# %% [markdown]
# <a href="https://colab.research.google.com/github/WesleySouza13/ESTUDOS/blob/main/Artistas_de_hiphop_mais_ouvidos_no_spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import  matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/top_hiphop_artists_tracks.csv')
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
#organizando dados
df.columns
graf1 = df.groupby('Artist').count()
graf1= df.groupby('Artist').count().Popularity.sort_values(ascending = False)

# %%
#plotar grafico de popularidade por artistas
plt.figure(figsize = (20,7))
plt.bar(graf1.index,graf1.values)
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.sort_values('Track Name', ascending = True).head(5)
# Out:
#            Artist                               Track Name  Popularity  \
# 333  Lil Uzi Vert                                   20 Min          84
# 275      Lil Durk  3 Headed Goat (feat. Lil Baby & Polo G)          75
# 41      Jung Kook                   3D (feat. Jack Harlow)          84
# 108         JAY-Z                                     4:44          74
# 69      Lil Wayne                            6 Foot 7 Foot          74
#
#      Duration (ms)                Track ID
# 333         220586  0uxSUdBrJy9Un0EYoBowng
# 275         169531  6Tguhaf2uAe6OjRLsR2Tql
# 41          201812  01qFKNWq73UfEslI0GvumE
# 108         284493  1gT5TGwbkkkUliNzHRIGi1
# 69          248586  5Qy6a5KzM4XlRxsNcGYhgH

# %%
df.sort_values('Popularity', ascending = False).head(5)
# Out:
#            Artist                  Track Name  Popularity  Duration (ms)  \
# 40    Jack Harlow                 Lovin On Me          97         138411
# 280            ¥$                    CARNIVAL          96         264324
# 70      21 Savage                      redrum          96         270697
# 260            ¥$                    CARNIVAL          96         264324
# 30   Travis Scott  FE!N (feat. Playboi Carti)          93         191700
#
#                    Track ID
# 40   4xhsWYTOGcal8zt0J161CU
# 280  3w0w2T288dec0mgeZZqoNN
# 70   52eIcoLUM25zbQupAZYoFh
# 260  3w0w2T288dec0mgeZZqoNN
# 30   42VsgItocQwOQC3XWZ8JNA

# %%
df.sort_values('Duration (ms)',ascending = False).head(5)
# Out:
#              Artist                                         Track Name  \
# 419       DJ Khaled  GOD DID (feat. Rick Ross, Lil Wayne, Jay-Z, Jo...
# 88           Eminem                                               Stan
# 91   Kendrick Lamar                                        Money Trees
# 173    Travis Scott                          SKITZO (feat. Young Thug)
# 62            Drake                                            Forever
#
#      Popularity  Duration (ms)                Track ID
# 419          64         501648  2sOj9vyd6yiss9W1IK6chU
# 88           84         404106  3UmaczJpikHgJFyBTAJVoz
# 91           82         386906  2HbKqm4o0w5wEeEFXm2sD4
# 173          78         366592  0bkV1iQHSxBaksUqgEkcbc
# 62           77         357706  5UsLjwBaTHBX4ektWIr4XX
